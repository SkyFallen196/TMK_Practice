# %%
# !pip install marker-pdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 580.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 575.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 607.7 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 1.4 MB/s eta 0:00:0000:0100:010m
# ...
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
# ...

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------
# aiohttp                                  3.9.5
# aiosignal                                1.3.1
# albucore                                 0.0.12
# albumentations                           1.4.10
# annotated-types                          0.7.0
# anyio                                    4.2.0
# appnope                                  0.1.2
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# asttokens                                2.0.5
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# Babel                                    2.11.0
# backoff                                  2.2.1
# bcrypt                                   4.1.3
# ...

# %%
# !pip show marker-pdf
# Out:
# Name: marker-pdf
# Version: 0.2.15
# Summary: Convert PDF to markdown with high speed and accuracy.
# Home-page: https://github.com/VikParuchuri/marker
# Author: Vik Paruchuri
# Author-email: github@vikas.sh
# License: GPL-3.0-or-later
# Location: /opt/anaconda3/envs/Gemeni_assist/lib/python3.10/site-packages
# Requires: filetype, ftfy, grpcio, numpy, pdftext, Pillow, pydantic, pydantic-settings, python-dotenv, rapidfuzz, regex, scikit-learn, surya-ocr, tabulate, texify, torch, tqdm, transformers
# Required-by:

# %%
# !cd /opt/anaconda3/envs/Gemeni_assist/lib/python3.10/site-packages && ls
# Out:
# Babel-2.11.0.dist-info
# Brotli-1.0.9.dist-info
# CHANGELOG.md
# Deprecated-1.2.14.dist-info
# IPython
# Levenshtein
# Levenshtein-0.25.1.dist-info
# Markdown-3.6.dist-info
# MarkupSafe-2.1.3.dist-info
# PIL
# PyJWT-2.8.0.dist-info
# PyMuPDF-1.24.7.dist-info
# PyMuPDFb-1.24.6.dist-info
# PyPika-0.48.9.dist-info
# PySocks-1.7.1.dist-info
# PyYAML-6.0.1.dist-info
# Pygments-2.15.1.dist-info
# QtPy-2.4.1.dist-info
# README.md
# README.txt
# SQLAlchemy-2.0.31.dist-info
# Send2Trash-1.8.2.dist-info
# __pycache__
# _argon2_cffi_bindings
# _brotli.cpython-310-darwin.so
# _cffi_backend.cpython-310-darwin.so
# _distutils_hack
# _multiprocess
# _ruamel_yaml.cpython-310-darwin.so
# _yaml
# aiohttp
# aiohttp-3.9.5.dist-info
# aiosignal
# aiosignal-1.3.1.dist-info
# albucore
# albucore-0.0.12.dist-info
# albumentations
# albumentations-1.4.10.dist-info
# annotated_types
# annotated_types-0.7.0.dist-info
# anyio
# anyio-4.2.0.dist-info
# apiclient
# app.py
# appnope
# appnope-0.1.2.dist-info
# ...

# %%
# !cd /opt/anaconda3/envs/Gemeni_assist/lib/python3.10/site-packages/marker && ls
# !open /opt/anaconda3/envs/Gemeni_assist/lib/python3.10/site-packages/marker/settings.py
# Out:
# __pycache__    debug          logger.py      pdf            tables
# benchmark      equations      models.py      postprocessors utils.py
# cleaners       images         ocr            schema
# convert.py     layout         output.py      settings.py

# %%
# !pip install ocrmypdf

# %%
# !marker_single "/Users/denisgorbunov/Documents/GitHub/TMK_Practice/data/gost_873278_extra_high.pdf" "/Users/denisgorbunov/Documents/GitHub/TMK_Practice/converted_data" --batch_multiplier 1 --langs Russian
# Out:
# Loaded detection model vikp/surya_det2 on device cpu with dtype torch.float32
# Loaded detection model vikp/surya_layout2 on device cpu with dtype torch.float32
# Loaded reading order model vikp/surya_order on device mps with dtype torch.float16
# Loaded recognition model vikp/surya_rec on device mps with dtype torch.float16
# Loaded texify model to mps with torch.float16 dtype
# ...
# Finding reading order: 100%|██████████████████████| 2/2 [00:19<00:00, 10.00s/it]
# Saved markdown to the /Users/denisgorbunov/Documents/GitHub/TMK_Practice/converted_data/gost_873278_extra_high folder
